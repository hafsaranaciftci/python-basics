# %% [markdown]
# <a href="https://colab.research.google.com/github/hafsaranaciftci/python-basics/blob/main/02_donguler_loops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=int(input("Bir sayı giriniz:"))
while x <= 0 :
  print("Sayınız negatif lütfen pozitif sayı girin.")
  x=int(input("Bir sayı giriniz:"))
print("Sayınız pozitif ve", x)





toplam=0
x=0

while x<=1000:
  toplam += x #toplamın değerini x kadar arttır demek
  x += 1 # x'i 1 er arttırır
print(toplam) #sonuç olarak 0dan 1000 e kadar olan sayıları toplamış oldu



for i in "selam": #eleman sayısı kadar kodu çalıştırdı ve her adımda in den sonra tanımlanan elemanın değerlerini almış oldu
  print(i)




toplam=0
for x in range(1001): #range içindekinin 1 eksiği kadar döngüye giriyor
  toplam += x
print(toplam) #while ile yaptığım kodun for a uyarlanmış hali




us=1
for i in range(10): #buradaki i değişkeni önemsiz sadece belli bir sayıda gerçekleşmesi için koyduk
  us*=5
print(us) #5 üssü 10 yazılmış oldu

us=1
for _ in range(10): #yukarıdaki kodun insanlar tarafından genel kullanılan hali anlaşılması açısından
  us*=5
print(us)


for i in range(10):
  if i == 8:
   break #döngüden çıkmak için
  print(i)


while x<10:
  print(x)
  x += 1
  if x == 8:
     break
  print(x) #yukarıdaki kodun while kullanılmış hali

for i in range(10):

    if i == 3:
        continue #3 ü atlayarak devam etti
    print(i)

x = 0
while x < 10:
   x += 1
   if x == 3:
      continue

   print(x)
# Out:
# Bir sayı giriniz:5
# Sayınız pozitif ve 5
# 500500
# s
# e
# l
# a
# m
# 500500
# 9765625
# 9765625
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 0
# 1
# 2
# 4
# 5
# 6
# 7
# 8
# 9
# 1
# 2
# 4
# 5
# 6
# 7
# 8
# 9
# 10
