# %% [markdown]
# <a href="https://colab.research.google.com/github/hafsaranaciftci/phyton-basics/blob/main/python_egitim_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(type(2.8))
print(int(2.5)) #sadece tam kısmı bastırır
print(float(5.9)) #içindekini bastırır

a=2
b=a+5
a=a+3 #a'ya yeni değişken atamak oluyor
print(a+10)



"Bana bugün \"Bugün ne yapıyorsun?\" dedi" # \ kendisinden sonraki " işaretini normal tırnak olarak bastırdı

print( "hey \nnaber") # \n satır atlattı

print("hey \tnaber") #\t boşluk bıraktı

"5" + "4" # burada iki str yi bitişik yazar toplama yazmaz çünkü sayı değil yazı olarak algıladı

4* "selam"  #4 tane bitişik selam


len("merhaba rana!") # boşluk dahil karakterlerin sayısı


isim="hafsa"

isim[3] #indexing 0dan baslar

isim[0:2] #slicing 2yi almadı 0 ve 1 i aldı

isim[0:] #bütün str yi aldı

isim[0:3:2] #sondaki 2, adım sayısı

isim[-1] #sondan başlatıyor saymayı

x=input("bir sayı girin:")
print(int(x)+10)

x=int(float("3.9"))
y=3
x==y

x=int(input("Bir sayı giriniz:"))

if x % 2 == 0 :
  print("Çift sayı")
else :
  print("Tek sayı")

print("Program sona ulaştı.")
# Out:
# <class 'float'>
# 2
# 5.9
# 15
# hey
# naber
# hey 	naber
# bir sayı girin:3
# 13
# Bir sayı giriniz:4
# Çift sayı
# Program sona ulaştı.
